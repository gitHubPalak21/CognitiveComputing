# %% [markdown]
# # palak
# # 102316112

# %% [markdown]
# # question 1

# %%
from IPython.display import Image, display

# Display the uploaded image
display(Image(filename='WhatsApp Image 2025-05-04 at 01.30.52_aefaf700.jpg'))

# %%
display(Image(filename='WhatsApp Image 2025-05-04 at 01.31.17_81cd1aaa.jpg'))

# %%
display(Image(filename='WhatsApp Image 2025-05-04 at 01.48.09_7ee04635.jpg'))

# %% [markdown]
# # question 2

# %%
display(Image(filename='Screenshot 2025-05-04 022301.png'))

# %%
display(Image(filename='WhatsApp Image 2025-05-04 at 02.11.05_8a89d510.jpg'))
